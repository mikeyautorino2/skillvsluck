# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

FILES = [
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0.csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (1).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (2).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (3).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (4).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (5).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (6).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (7).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (8).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (9).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (10).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (11).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (12).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (13).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (14).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (15).csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (16).csv",

    # Data loading issue (03-04 and 04-05 season)
    # "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (17).csv",
    # "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (18).csv",

    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (19).csv",

    # No betting data for these 2 (00-01, and 01-02 season)
    # "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (20).csv",
    # "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/E0 (21).csv",

    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/football_data_premier_league_2022_23.csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/football_data_premier_league_2023_24.csv",
    "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/football_data_premier_league_2024_25.csv",
]

frames = []
for fp in FILES:
    df_i = pd.read_csv(fp, low_memory=False)
    frames.append(df_i)

df_raw = pd.concat(frames, ignore_index=True)

df_raw.sample(n=10)
# Out:
#      Div        Date   Time   HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 5965  E0    10/02/07    NaN   West Ham    Watford   0.0   1.0   A   0.0   1.0
# 168   E0  19/12/2021  16:30  Tottenham  Liverpool   2.0   2.0   D   1.0   1.0
# 1229  E0  22/10/2018    NaN    Arsenal  Leicester   3.0   1.0   H   1.0   1.0
# 1190  E0  22/09/2018    NaN   Brighton  Tottenham   1.0   2.0   A   0.0   1.0
# 1701  E0  23/12/2017    NaN   Brighton    Watford   1.0   0.0   H   0.0   0.0
# 6463  E0  17/08/2002    NaN    Everton  Tottenham   2.0   2.0   D   1.0   0.0
# 6484  E0  28/08/2002    NaN  Blackburn  Liverpool   2.0   2.0   D   1.0   1.0
# 867   E0  02/11/2019  17:30    Watford    Chelsea   1.0   2.0   A   0.0   1.0
# 2695  E0    13/09/14    NaN      Stoke  Leicester   0.0   1.0   A   0.0   0.0
# 6750  E0  08/03/2003    NaN  Liverpool     Bolton   2.0   0.0   H   1.0   0.0
#
#       ... 1XBCH 1XBCD  1XBCA  BFECH  BFECD  BFECA  BFEC>2.5  BFEC<2.5  \
# ...

# %%
print(list(df_raw.columns))
# Out:
# ['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5', 'B365<2.5', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH', 'AvgAHA', 'B365CH', 'B365CD', 'B365CA', 'BWCH', 'BWCD', 'BWCA', 'IWCH', 'IWCD', 'IWCA', 'PSCH', 'PSCD', 'PSCA', 'WHCH', 'WHCD', 'WHCA', 'VCCH', 'VCCD', 'VCCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH', 'AvgCD', 'AvgCA', 'B365C>2.5', 'B365C<2.5', 'PC>2.5', 'PC<2.5', 'MaxC>2.5', 'MaxC<2.5', 'AvgC>2.5', 'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH', 'MaxCAHA', 'AvgCAHH', 'AvgCAHA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD', 'BbMxA', 'BbAvA', 'BbOU', 'BbMx
# ...

# %%
need = ["Date", "HomeTeam", "AwayTeam", "FTHG", "FTAG", "FTR", "MW", "B365H", "B365D", "B365A"]

have = [c for c in need if c in df_raw.columns]
df = df_raw[have].copy()
df.sample(n=10)
# Out:
#             Date          HomeTeam       AwayTeam  FTHG  FTAG FTR  B365H  \
# 6218    03/12/05            Bolton        Arsenal   2.0   0.0   H   4.33
# 4135    16/04/12           Arsenal          Wigan   1.0   2.0   A   1.25
# 631   27/02/2021         Newcastle         Wolves   1.0   1.0   D   3.50
# 5736    09/09/06  Sheffield United      Blackburn   0.0   0.0   D   2.62
# 7689  27/10/2024          West Ham     Man United   2.0   1.0   H   2.88
# 5239    22/03/09             Wigan           Hull   1.0   0.0   H   1.72
# 7544  20/04/2024             Luton      Brentford   1.0   5.0   A   3.10
# 3936    03/12/11             Wigan        Arsenal   0.0   4.0   A   6.00
# 1534  19/08/2017       Southampton       West Ham   3.0   2.0   H   1.75
# 7681  25/10/2024         Leicester  Nott'm Forest   1.0   3.0   A   3.00
#
#       B365D  B365A
# 6218   3.30   1.83
# 4135   6.00  12.00
# 631    3.20   2.20
# 5736   3.20   2.62
# 7689   3.75   2.30
# 5239   3.60   5.00
# 7544   3.75   2.15
# ...

# %% [markdown]
# # Variable Titles
#
# Date = Match Date (dd/mm/yy)
#
# HomeTeam = Home Team
#
# Away team = Away Team
#
# FTHG = Full Time Home Team Goals
#
# FTAG = Full-Time Away Team Goals
#
# FTR = Full-Time Result (H=Home Win, D=Draw, A=Away Win)
#
# MW = Match Week
#
# B365H = Bet365's Home Team Win Odd.
#
# B365D = Bet365's Draw Odd.
#
# B365A = Bet365's Away Team Win Odd.

# %%
df["Date"] = df["Date"].astype(str).str.replace("\u00a0", " ", regex=False).str.strip()

df["date"] = pd.to_datetime(df["Date"], errors="coerce", dayfirst=True)

m = df["date"].isna() & df["Date"].notna()

if m.any():
    # second pass for leftovers (rare alt formats)
    df.loc[m, "date"] = pd.to_datetime(df.loc[m, "Date"], errors="coerce", dayfirst=False)

# --- Season = START YEAR ONLY (e.g., 2001 for 2001/02) ---
season = df["date"].dt.year
season = season.where(df["date"].dt.month >= 8, season - 1)
df["season"] = season.astype("Int64")
# Out:
# /tmp/ipython-input-401290040.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.loc[m, "date"] = pd.to_datetime(df.loc[m, "Date"], errors="coerce", dayfirst=False)

# %%
df = df.rename(columns={"HomeTeam": "home_team", "AwayTeam": "away_team"})

df["hometeamgoals"] = pd.to_numeric(df.get("FTHG"), errors="coerce").astype("Int64")
df["awayteamgoals"] = pd.to_numeric(df.get("FTAG"), errors="coerce").astype("Int64")

win_mask   = df["hometeamgoals"].gt(df["awayteamgoals"]).fillna(False)
loss_mask  = df["hometeamgoals"].lt(df["awayteamgoals"]).fillna(False)
known_mask = df["hometeamgoals"].notna() & df["awayteamgoals"].notna()

df["hometeamresult"] = pd.NA
df.loc[win_mask,  "hometeamresult"] = "win"
df.loc[loss_mask, "hometeamresult"] = "loss"
df.loc[~win_mask & ~loss_mask & known_mask, "hometeamresult"] = "draw"

df["home_team_points"] = pd.NA
df["away_team_points"] = pd.NA
df.loc[win_mask,  ["home_team_points", "away_team_points"]] = [3, 0]
df.loc[loss_mask, ["home_team_points", "away_team_points"]] = [0, 3]
df.loc[~win_mask & ~loss_mask & known_mask, ["home_team_points", "away_team_points"]] = [1, 1]

df[["home_team_points","away_team_points"]] = df[["home_team_points","away_team_points"]].astype("Int64")

# %%
if "MW" in df.columns:
    df = df.rename(columns={"MW": "week"})

odds_map = {"B365H": "OddHome", "B365D": "OddDraw", "B365A": "OddAway"}
for src, dst in odds_map.items():
    if src in df.columns:
        df = df.rename(columns={src: dst})
        df[dst] = pd.to_numeric(df[dst], errors="coerce")

final_cols = ["season", "date"]
if "week" in df.columns:
    final_cols.append("week")


final_cols += [
    "home_team", "away_team",
    "hometeamgoals", "awayteamgoals",
    "hometeamresult", "home_team_points", "away_team_points",
    "OddHome", "OddDraw", "OddAway",
]

final_df = df[[c for c in final_cols if c in df.columns]] \
    .sort_values(["season", "date"], ascending=[False, False], ignore_index=True)

# %%
final_df.sample(n=10)
# Out:
#       season       date   home_team    away_team  hometeamgoals  \
# 4444    2013 2013-10-27  Sunderland    Newcastle              2
# 851     2022 2023-04-08   Tottenham     Brighton              2
# 7774    2002 2002-12-28   Blackburn     West Ham              2
# 634     2023 2023-11-25     Burnley     West Ham              1
# 7766    2002 2003-01-01     Everton     Man City              2
# 3027    2017 2017-09-04     Everton    Leicester              4
# 2695    2017 2018-04-28     Swansea      Chelsea              0
# 1904    2019 2020-07-26     Everton  Bournemouth              1
# 1905    2019 2020-07-26   Leicester   Man United              0
# 2484    2018 2018-12-22     Chelsea    Leicester              0
#
#       awayteamgoals hometeamresult  home_team_points  away_team_points  \
# 4444              1            win                 3                 0
# 851               1            win                 3                 0
# ...

# %%
full_path = "/content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/premier_league.csv"

final_df.to_csv(full_path, index=False)

print("Saved:", full_path)
# Out:
# Saved: /content/drive/MyDrive/Sophomore Year/IML_Fall2025_SkillVersusLuck/Premier League/premier_league.csv

# %%
import pandas as pd
import numpy as np

def get_result(result):
    if pd.isna(result):
        return None
    if result == "win":  # 
        return 1 #
    if result == "draw":  # 
        return 0
    else:  #
        return -1 #

final_df = pd.read_csv("/Users/joeyli/skillvsluck/data/european_soccer/data/processed/premier_league.csv")
final_df["hometeamresult"] = final_df["hometeamresult"].apply(get_result)
final_df.to_csv("premier_league.csv", index = False)
